# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd # Data manipulation and analysis
import numpy as np # Numerical operations
import matplotlib.pyplot as plt # Data visualization
import seaborn as sns # Data visualization
import plotly.express as px # Data visualization
from plotly.subplots import make_subplots # Data visualization
import plotly.graph_objects as go # Data visualization
import cufflinks as cf # Create interactive plot directly from pandas DataFrames
from scipy import stats # Statistical test and analysis
from scipy.stats import ttest_ind # Statistical test and analysis
from statsmodels.stats.proportion import proportions_ztest # Statistical test and analysis
from sklearn.metrics import confusion_matrix, classification_report # Advanced analysis

# %% [markdown]
# # 2. Load Datasets

# %% [markdown]
# ## 2.1 Control Dataset

# %%
control_url = 'https://github.com/nuraulaola/Campaign-A-B-Testing-with-Python/raw/main/Datasets/control_group.csv'
control_df = pd.read_csv(control_url, sep = ";")
control_df.head()
# Out:
#       Campaign Name       Date  Spend [USD]  # of Impressions     Reach  \
# 0  Control Campaign  1.08.2019         2280           82702.0   56930.0
# 1  Control Campaign  2.08.2019         1757          121040.0  102513.0
# 2  Control Campaign  3.08.2019         2343          131711.0  110862.0
# 3  Control Campaign  4.08.2019         1940           72878.0   61235.0
# 4  Control Campaign  5.08.2019         1835               NaN       NaN
#
#    # of Website Clicks  # of Searches  # of View Content  # of Add to Cart  \
# 0               7016.0         2290.0             2159.0            1819.0
# 1               8110.0         2033.0             1841.0            1219.0
# 2               6508.0         1737.0             1549.0            1134.0
# 3               3065.0         1042.0              982.0            1183.0
# 4                  NaN            NaN                NaN               NaN
#
#    # of Purchase
# 0          618.0
# 1          511.0
# 2          372.0
# 3          340.0
# 4            NaN

# %%
control_df.columns
# Out:
# Index(['Campaign Name', 'Date', 'Spend [USD]', '# of Impressions', 'Reach',
#        '# of Website Clicks', '# of Searches', '# of View Content',
#        '# of Add to Cart', '# of Purchase'],
#       dtype='object')

# %%
# Clean up column names
control_df.columns = ["campaign_name", "date", "spend_usd", "impressions", "reach", "website_clicks", "searches", "view_content", "add_to_cart", "purchase"]
control_df.head()
# Out:
#       campaign_name       date  spend_usd  impressions     reach  \
# 0  Control Campaign  1.08.2019       2280      82702.0   56930.0
# 1  Control Campaign  2.08.2019       1757     121040.0  102513.0
# 2  Control Campaign  3.08.2019       2343     131711.0  110862.0
# 3  Control Campaign  4.08.2019       1940      72878.0   61235.0
# 4  Control Campaign  5.08.2019       1835          NaN       NaN
#
#    website_clicks  searches  view_content  add_to_cart  purchase
# 0          7016.0    2290.0        2159.0       1819.0     618.0
# 1          8110.0    2033.0        1841.0       1219.0     511.0
# 2          6508.0    1737.0        1549.0       1134.0     372.0
# 3          3065.0    1042.0         982.0       1183.0     340.0
# 4             NaN       NaN           NaN          NaN       NaN

# %% [markdown]
# ## 2.2 Test Dataset

# %%
test_url = 'https://github.com/nuraulaola/Campaign-A-B-Testing-with-Python/raw/main/Datasets/test_group.csv'
test_df = pd.read_csv(test_url, sep = ";")
test_df.head()
# Out:
#    Campaign Name       Date  Spend [USD]  # of Impressions  Reach  \
# 0  Test Campaign  1.08.2019         3008             39550  35820
# 1  Test Campaign  2.08.2019         2542            100719  91236
# 2  Test Campaign  3.08.2019         2365             70263  45198
# 3  Test Campaign  4.08.2019         2710             78451  25937
# 4  Test Campaign  5.08.2019         2297            114295  95138
#
#    # of Website Clicks  # of Searches  # of View Content  # of Add to Cart  \
# 0                 3038           1946               1069               894
# 1                 4657           2359               1548               879
# 2                 7885           2572               2367              1268
# 3                 4216           2216               1437               566
# 4                 5863           2106                858               956
#
#    # of Purchase
# 0            255
# 1            677
# 2            578
# 3            340
# 4            768

# %%
test_df.columns
# Out:
# Index(['Campaign Name', 'Date', 'Spend [USD]', '# of Impressions', 'Reach',
#        '# of Website Clicks', '# of Searches', '# of View Content',
#        '# of Add to Cart', '# of Purchase'],
#       dtype='object')

# %%
# Clean up column names
test_df.columns = ["campaign_name", "date", "spend_usd", "impressions", "reach", "website_clicks", "searches", "view_content", "add_to_cart", "purchase"]
test_df.head()
# Out:
#    campaign_name       date  spend_usd  impressions  reach  website_clicks  \
# 0  Test Campaign  1.08.2019       3008        39550  35820            3038
# 1  Test Campaign  2.08.2019       2542       100719  91236            4657
# 2  Test Campaign  3.08.2019       2365        70263  45198            7885
# 3  Test Campaign  4.08.2019       2710        78451  25937            4216
# 4  Test Campaign  5.08.2019       2297       114295  95138            5863
#
#    searches  view_content  add_to_cart  purchase
# 0      1946          1069          894       255
# 1      2359          1548          879       677
# 2      2572          2367         1268       578
# 3      2216          1437          566       340
# 4      2106           858          956       768

# %% [markdown]
# # 3. Exploratory Data Analysis (EDA) of Each DF

# %% [markdown]
# ## 3.1 Data Summary

# %% [markdown]
# ### 3.1.1 Control DF Summary

# %%
control_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_name   30 non-null     object
#  1   date            30 non-null     object
#  2   spend_usd       30 non-null     int64
#  3   impressions     29 non-null     float64
#  4   reach           29 non-null     float64
#  5   website_clicks  29 non-null     float64
#  6   searches        29 non-null     float64
#  7   view_content    29 non-null     float64
#  8   add_to_cart     29 non-null     float64
#  9   purchase        29 non-null     float64
# dtypes: float64(7), int64(1), object(2)
# memory usage: 2.5+ KB

# %%
# Convert 'date' column to datetime
control_df['date'] = pd.to_datetime(control_df['date'])
control_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_name   30 non-null     object
#  1   date            30 non-null     datetime64[ns]
#  2   spend_usd       30 non-null     int64
#  3   impressions     29 non-null     float64
#  4   reach           29 non-null     float64
#  5   website_clicks  29 non-null     float64
#  6   searches        29 non-null     float64
#  7   view_content    29 non-null     float64
#  8   add_to_cart     29 non-null     float64
#  9   purchase        29 non-null     float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 2.5+ KB
# <ipython-input-9-1415cf248413>:2: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %% [markdown]
# ### 3.1.2 Test DF Summary

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_name   30 non-null     object
#  1   date            30 non-null     object
#  2   spend_usd       30 non-null     int64
#  3   impressions     30 non-null     int64
#  4   reach           30 non-null     int64
#  5   website_clicks  30 non-null     int64
#  6   searches        30 non-null     int64
#  7   view_content    30 non-null     int64
#  8   add_to_cart     30 non-null     int64
#  9   purchase        30 non-null     int64
# dtypes: int64(8), object(2)
# memory usage: 2.5+ KB

# %%
# Convert 'date' column to datetime
test_df['date'] = pd.to_datetime(test_df['date'])
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_name   30 non-null     object
#  1   date            30 non-null     datetime64[ns]
#  2   spend_usd       30 non-null     int64
#  3   impressions     30 non-null     int64
#  4   reach           30 non-null     int64
#  5   website_clicks  30 non-null     int64
#  6   searches        30 non-null     int64
#  7   view_content    30 non-null     int64
#  8   add_to_cart     30 non-null     int64
#  9   purchase        30 non-null     int64
# dtypes: datetime64[ns](1), int64(8), object(1)
# memory usage: 2.5+ KB
# <ipython-input-11-5b619521151e>:2: UserWarning:
#
# Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.

# %% [markdown]
# ## 3.2 Descriptive Statistics

# %% [markdown]
# ### 3.2.1 Control DF Descriptive Statistics

# %%
control_df.describe()
# Out:
#          spend_usd    impressions          reach  website_clicks     searches  \
# count    30.000000      29.000000      29.000000       29.000000    29.000000
# mean   2288.433333  109559.758621   88844.931034     5320.793103  2221.310345
# std     367.334451   21688.922908   21832.349595     1757.369003   866.089368
# min    1757.000000   71274.000000   42859.000000     2277.000000  1001.000000
# 25%    1945.500000   92029.000000   74192.000000     4085.000000  1615.000000
# 50%    2299.500000  113430.000000   91579.000000     5224.000000  2390.000000
# 75%    2532.000000  121332.000000  102479.000000     6628.000000  2711.000000
# max    3083.000000  145248.000000  127852.000000     8137.000000  4891.000000
#
#        view_content  add_to_cart    purchase
# count     29.000000    29.000000   29.000000
# mean    1943.793103  1300.000000  522.793103
# std      777.545469   407.457973  185.028642
# min      848.000000   442.000000  222.000000
# 25%     1249.000000   930.000000  372.000000
# 50%     1984.000000  1339.000000  501.000000
# 75%     2421.000000  1641.000000  670.000000
# max     4219.000000  1913.000000  800.000000

# %% [markdown]
# ### 3.2.2 Test DF Descriptive Statistics

# %%
test_df.describe()
# Out:
#          spend_usd    impressions          reach  website_clicks     searches  \
# count    30.000000      30.000000      30.000000       30.000000    30.000000
# mean   2563.066667   74584.800000   53491.566667     6032.333333  2418.966667
# std     348.687681   32121.377422   28795.775752     1708.567263   388.742312
# min    1968.000000   22521.000000   10598.000000     3038.000000  1854.000000
# 25%    2324.500000   47541.250000   31516.250000     4407.000000  2043.000000
# 50%    2584.000000   68853.500000   44219.500000     6242.500000  2395.500000
# 75%    2836.250000   99500.000000   78778.750000     7604.750000  2801.250000
# max    3112.000000  133771.000000  109834.000000     8264.000000  2978.000000
#
#        view_content  add_to_cart    purchase
# count     30.000000    30.000000   30.000000
# mean    1858.000000   881.533333  521.233333
# std      597.654669   347.584248  211.047745
# min      858.000000   278.000000  238.000000
# 25%     1320.000000   582.500000  298.000000
# 50%     1881.000000   974.000000  500.000000
# 75%     2412.000000  1148.500000  701.000000
# max     2801.000000  1391.000000  890.000000

# %% [markdown]
# ## 3.3 Check for Missing Values

# %% [markdown]
# ### 3.3.1 Check for Missing Values in Control DF

# %%
control_df.isnull().sum()
# Out:
# campaign_name     0
# date              0
# spend_usd         0
# impressions       1
# reach             1
# website_clicks    1
# searches          1
# view_content      1
# add_to_cart       1
# purchase          1
# dtype: int64

# %%
# Fill missing values with the mean of column
control_df['impressions'] = control_df['impressions'].fillna(control_df['impressions'].mean())
control_df['reach'] = control_df['reach'].fillna(control_df['reach'].mean())
control_df['website_clicks'] = control_df['website_clicks'].fillna(control_df['website_clicks'].mean())
control_df['searches'] = control_df['searches'].fillna(control_df['searches'].mean())
control_df['view_content'] = control_df['view_content'].fillna(control_df['view_content'].mean())
control_df['add_to_cart'] = control_df['add_to_cart'].fillna(control_df['add_to_cart'].mean())
control_df['purchase'] = control_df['purchase'].fillna(control_df['purchase'].mean())

control_df.head()
# Out:
#       campaign_name       date  spend_usd    impressions          reach  \
# 0  Control Campaign 2019-01-08       2280   82702.000000   56930.000000
# 1  Control Campaign 2019-02-08       1757  121040.000000  102513.000000
# 2  Control Campaign 2019-03-08       2343  131711.000000  110862.000000
# 3  Control Campaign 2019-04-08       1940   72878.000000   61235.000000
# 4  Control Campaign 2019-05-08       1835  109559.758621   88844.931034
#
#    website_clicks     searches  view_content  add_to_cart    purchase
# 0     7016.000000  2290.000000   2159.000000       1819.0  618.000000
# 1     8110.000000  2033.000000   1841.000000       1219.0  511.000000
# 2     6508.000000  1737.000000   1549.000000       1134.0  372.000000
# 3     3065.000000  1042.000000    982.000000       1183.0  340.000000
# 4     5320.793103  2221.310345   1943.793103       1300.0  522.793103

# %% [markdown]
# ### 3.3.2 Check for Missing Values in Test DF

# %%
test_df.isnull().sum()
# Out:
# campaign_name     0
# date              0
# spend_usd         0
# impressions       0
# reach             0
# website_clicks    0
# searches          0
# view_content      0
# add_to_cart       0
# purchase          0
# dtype: int64

# %% [markdown]
# ## 3.4 Check for Duplicates

# %% [markdown]
# ### 3.4.1 Check for Duplicates in Control DF

# %%
# Check for duplicates in control_df
controldf_duplicate_rows = control_df[control_df.duplicated()]

# Display duplicate rows
print("Duplicate Rows:")
print(controldf_duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [campaign_name, date, spend_usd, impressions, reach, website_clicks, searches, view_content, add_to_cart, purchase]
# Index: []

# %% [markdown]
# ### 3.4.2 Check for Duplicates in Test DF

# %%
# Check for duplicates in test_df
testdf_duplicate_rows = test_df[test_df.duplicated()]

# Display duplicate rows
print("Duplicate Rows:")
print(testdf_duplicate_rows)
# Out:
# Duplicate Rows:
# Empty DataFrame
# Columns: [campaign_name, date, spend_usd, impressions, reach, website_clicks, searches, view_content, add_to_cart, purchase]
# Index: []

# %% [markdown]
# # 4. Datasets Merge

# %%
ab_df = control_df.merge(test_df, how='outer').sort_values(['date']).reset_index(drop=True)
ab_df.head()
# Out:
# <ipython-input-19-ff03bbcba0d8>:1: UserWarning:
#
# You are merging on int and float columns where the float values are not equal to their int representation.
#       campaign_name       date  spend_usd  impressions     reach  \
# 0  Control Campaign 2019-01-08       2280      82702.0   56930.0
# 1     Test Campaign 2019-01-08       3008      39550.0   35820.0
# 2  Control Campaign 2019-02-08       1757     121040.0  102513.0
# 3     Test Campaign 2019-02-08       2542     100719.0   91236.0
# 4  Control Campaign 2019-03-08       2343     131711.0  110862.0
#
#    website_clicks  searches  view_content  add_to_cart  purchase
# 0          7016.0    2290.0        2159.0       1819.0     618.0
# 1          3038.0    1946.0        1069.0        894.0     255.0
# 2          8110.0    2033.0        1841.0       1219.0     511.0
# 3          4657.0    2359.0        1548.0        879.0     677.0
# 4          6508.0    1737.0        1549.0       1134.0     372.0

# %%
ab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   campaign_name   60 non-null     object
#  1   date            60 non-null     datetime64[ns]
#  2   spend_usd       60 non-null     int64
#  3   impressions     60 non-null     float64
#  4   reach           60 non-null     float64
#  5   website_clicks  60 non-null     float64
#  6   searches        60 non-null     float64
#  7   view_content    60 non-null     float64
#  8   add_to_cart     60 non-null     float64
#  9   purchase        60 non-null     float64
# dtypes: datetime64[ns](1), float64(7), int64(1), object(1)
# memory usage: 4.8+ KB

# %%
ab_df.describe()
# Out:
#          spend_usd    impressions          reach  website_clicks     searches  \
# count    60.000000      60.000000      60.000000       60.000000    60.000000
# mean   2425.750000   92072.279310   71168.248851     5676.563218  2320.138506
# std     381.130461   32270.541283   30847.039691     1740.469866   663.473391
# min    1757.000000   22521.000000   10598.000000     2277.000000  1001.000000
# 25%    2073.750000   69558.250000   43235.500000     4230.750000  1970.750000
# 50%    2420.500000   98281.000000   77422.000000     5581.000000  2374.500000
# 75%    2727.500000  117160.500000   95314.250000     7201.250000  2755.750000
# max    3112.000000  145248.000000  127852.000000     8264.000000  4891.000000
#
#        view_content  add_to_cart    purchase
# count     60.000000    60.000000   60.000000
# mean    1900.896552  1090.766667  522.013218
# std      681.437956   427.427479  195.297540
# min      848.000000   278.000000  222.000000
# 25%     1249.000000   863.250000  340.000000
# 50%     1959.396552  1082.500000  506.000000
# 75%     2422.500000  1384.250000  685.000000
# max     4219.000000  1913.000000  890.000000

# %% [markdown]
# # 5. A/B Testing

# %% [markdown]
# ## 5.1 Comparison of Key Metrics

# %%
campaign_metrics = ab_df.groupby('campaign_name').mean().reset_index()
melted_metrics = pd.melt(campaign_metrics, id_vars='campaign_name', var_name='Metric', value_name='Value')

fig = px.bar(melted_metrics, x='campaign_name', y='Value', color='Metric',
             labels={'Value': 'Mean Value'},
             title='Comparison of Metrics Between Control and Test Campaigns',
             barmode='group')
fig.show()
# Out:
# <ipython-input-22-4da461427084>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="db0cf5a8-0e99-4ee2-b5d6-976e82527418" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("db0cf5a8-0e99-4ee2-b5d6-976e82527418")) {                    Plotly.newPlot(                        "db0cf5a8-0e99-4ee2-b5d6-976e82527418",                        [{"alignmentgroup":"True","hovertemplate":"Metric=spend_usd\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"spend_usd","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"spend_usd","offsetgroup":"spend_usd","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[2288.4333333333334,2563.0666666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=impressions\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"impressions","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"impressions","offsetgroup":"impressions","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[109559.75862068965,74584.8],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=reach\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"reach","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"reach","offsetgroup":"reach","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[88844.93103448275,53491.566666666666],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=website_clicks\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"website_clicks","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"website_clicks","offsetgroup":"website_clicks","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[5320.793103448276,6032.333333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=searches\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"searches","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"searches","offsetgroup":"searches","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[2221.310344827586,2418.9666666666667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=view_content\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"view_content","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"view_content","offsetgroup":"view_content","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[1943.7931034482758,1858.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=add_to_cart\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"add_to_cart","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"add_to_cart","offsetgroup":"add_to_cart","orientation":"v","showlegend":true,"textposition":"auto","x":["Control Campaign","Test Campaign"],"xaxis":"x","y":[1300.0,881.5333333333333],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Metric=purchase\u003cbr\u003ecampaign_name=%{x}\u003cbr\u003eMean Value=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"purchase","marker" ...

# %% [markdown]
# From the plot, it is evident that the test campaign has higher spending than the control campaign, indicating that more financial resources were allocated to the test. This might have resulted in increased website clicks and searches, signifying improved user engagement (despite lower impressions and reach). The differences between the view_content and
# add_to_cart metrics suggest variations in user behavior between the campaigns. However, similar purchase metrics indicate that both campaigns had a comparable conversion rate.

# %% [markdown]
# ## 5.2 Trendline Plots

# %%
fig = px.scatter(data_frame=ab_df,
                 x='spend_usd',
                 y='reach',
                 size='impressions',
                 color='campaign_name',
                 trendline='ols')

fig.update_layout(xaxis_title='Spend (USD)',
                  yaxis_title='Reach',
                  title='Trendline of Spend (USD) vs. Reach by Campaign',
                  legend_title='Campaign Name')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e8e3098e-2f09-4703-a2c4-5e91841c287e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e8e3098e-2f09-4703-a2c4-5e91841c287e")) {                    Plotly.newPlot(                        "e8e3098e-2f09-4703-a2c4-5e91841c287e",                        [{"hovertemplate":"campaign_name=Control Campaign\u003cbr\u003espend_usd=%{x}\u003cbr\u003ereach=%{y}\u003cbr\u003eimpressions=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","size":[82702.0,121040.0,131711.0,72878.0,109559.75862068965,109076.0,142123.0,90939.0,82847.0,145248.0,132845.0,71274.0,119612.0,108452.0,107890.0,113430.0,74654.0,105705.0,129880.0,72515.0,117006.0,124897.0,104678.0,141654.0,92029.0,111306.0,121332.0,117624.0,115247.0,116639.0],"sizemode":"area","sizeref":363.12,"symbol":"circle"},"mode":"markers","name":"Control Campaign","orientation":"v","showlegend":true,"x":[2280,1757,2343,1940,1835,3083,2544,1900,2697,1875,2774,2024,2177,1876,2596,2675,1803,2939,2496,1892,1962,2233,2061,2421,2375,2324,2813,2149,2490,2319],"xaxis":"x","y":[56930.0,102513.0,110862.0,61235.0,88844.93103448275,87998.0,127852.0,65217.0,68214.0,118632.0,102479.0,42859.0,106518.0,96518.0,81268.0,78625.0,59873.0,86218.0,109413.0,51987.0,100398.0,98432.0,91579.0,125874.0,74192.0,88632.0,94896.0,91257.0,95843.0,100189.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ereach = 11.1067 * spend_usd + 63428.1\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.036168\u003cbr\u003e\u003cbr\u003ecampaign_name=Control Campaign\u003cbr\u003espend_usd=%{x}\u003cbr\u003ereach=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Control Campaign","showlegend":false,"x":[1757,1803,1835,1875,1876,1892,1900,1940,1962,2024,2061,2149,2177,2233,2280,2319,2324,2343,2375,2421,2490,2496,2544,2596,2675,2697,2774,2813,2939,3083],"xaxis":"x","y":[82942.47578087258,83453.38265222564,83808.79612794952,84253.06297260436,84264.16964372073,84441.87638158267,84530.72975051364,84974.99659516849,85219.34335972865,85907.95696894365,86318.90380024938,87296.29085849003,87607.27764974843,88229.2512322652,88751.26477473465,89184.42494827311,89239.95830385498,89450.98505506602,89806.39853078988,90317.30540214296,91083.66570917256,91150.30573587079,91683.4259494566,92260.97284750789,93138.39986570121,93382.74663026136,94237.96030622194,94671.12047976042,96070.56104042317,97669.9216811806],"yaxis":"y","type":"scatter"},{"hovertemplate":"campaign_name=Test Campaign\u003cbr\u003espend_usd=%{x}\u003cbr\u003ereach=%{y}\u003cbr\u003eimpressions=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","size":[39550.0,100719.0,70263.0,78451.0,114295.0,42684.0,53986.0,33669.0,65827.0,56304.0,94338.0,106584.0,95843.0,53632.0,22521.0,39470.0,133771.0,34752.0,60286.0,36650.0,120576.0,80841.0,111469.0,54627.0,67444.0,120203.0,45511.0,95054.0,83633.0,124591.0],"sizemode":"area","sizeref":363.12,"symbol":"circle"},"mode":"markers","name":"Test Campaign","orientation":"v","showlegend":true,"x":[3008,2542,2365,2710,2297,2458,2838,2916,1972,2537,2516,3076,1968,1979,2626,2712,3112,2899,2407,2078,2928,2311,2915,2247,2805,1977,2652,2790,2420,2831],"xaxis":"x","y":[35820.0,91236.0,45198.0,25937.0,95138.0,31489.0,42148.0,20149.0,49531.0,25982.0,76219.0,81389.0,54389.0,43241.0,10698.0,31893.0,109834.0,27932.0,49329.0,30489.0,105978.0,61589.0,92159.0,41267.0,43219.0,89380.0,31598.0,79632.0,71286.0,10598.0],"yaxis":"y","type":"scatter ...

# %% [markdown]
# As expected, allocating more budget to a campaign generally enables the campaign to reach a broader audience. The plot reveals a positive correlation between spending and reach. However, the size of the dots, representing the impressions metric, does not appear to exhibit a strong correlation with either spending or reach.

# %%
fig = px.scatter(data_frame=ab_df,
                 x='reach',
                 y='website_clicks',
                 size='impressions',
                 color='campaign_name',
                 trendline='ols')

fig.update_layout(xaxis_title='Reach',
                  yaxis_title='Website Clicks',
                  title='Trendline of Reach vs. Website Clicks by Campaign',
                  legend_title='Campaign Name')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ddbfc59d-71b1-4425-afe7-697d164a279d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ddbfc59d-71b1-4425-afe7-697d164a279d")) {                    Plotly.newPlot(                        "ddbfc59d-71b1-4425-afe7-697d164a279d",                        [{"hovertemplate":"campaign_name=Control Campaign\u003cbr\u003ereach=%{x}\u003cbr\u003ewebsite_clicks=%{y}\u003cbr\u003eimpressions=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","size":[82702.0,121040.0,131711.0,72878.0,109559.75862068965,109076.0,142123.0,90939.0,82847.0,145248.0,132845.0,71274.0,119612.0,108452.0,107890.0,113430.0,74654.0,105705.0,129880.0,72515.0,117006.0,124897.0,104678.0,141654.0,92029.0,111306.0,121332.0,117624.0,115247.0,116639.0],"sizemode":"area","sizeref":363.12,"symbol":"circle"},"mode":"markers","name":"Control Campaign","orientation":"v","showlegend":true,"x":[56930.0,102513.0,110862.0,61235.0,88844.93103448275,87998.0,127852.0,65217.0,68214.0,118632.0,102479.0,42859.0,106518.0,96518.0,81268.0,78625.0,59873.0,86218.0,109413.0,51987.0,100398.0,98432.0,91579.0,125874.0,74192.0,88632.0,94896.0,91257.0,95843.0,100189.0],"xaxis":"x","y":[7016.0,8110.0,6508.0,3065.0,5320.793103448276,4028.0,2640.0,7260.0,6554.0,4521.0,4896.0,5224.0,6628.0,7253.0,3706.0,2578.0,5691.0,6843.0,4410.0,4085.0,4234.0,5435.0,4941.0,6287.0,8127.0,4658.0,6198.0,2277.0,8137.0,2993.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003ewebsite_clicks = -0.00476576 * reach + 5744.21\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.003505\u003cbr\u003e\u003cbr\u003ecampaign_name=Control Campaign\u003cbr\u003ereach=%{x}\u003cbr\u003ewebsite_clicks=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Control Campaign","showlegend":false,"x":[42859.0,51987.0,56930.0,59873.0,61235.0,65217.0,68214.0,74192.0,78625.0,81268.0,86218.0,87998.0,88632.0,88844.93103448275,91257.0,91579.0,94896.0,95843.0,96518.0,98432.0,100189.0,100398.0,102479.0,102513.0,106518.0,109413.0,110862.0,118632.0,125874.0,127852.0],"xaxis":"x","y":[5539.951233370484,5496.449332573265,5472.892157327793,5458.866511617209,5452.375540003951,5433.398264699993,5419.115267691966,5390.625525912192,5369.498890698116,5356.902974417764,5333.312438818921,5324.829377532873,5321.807882670314,5320.793103448281,5309.297750155775,5307.763173900659,5291.955132167051,5287.441952932282,5284.225061714258,5275.103387949372,5266.729939252974,5265.733894416579,5255.81633793553,5255.654301933437,5236.567414039827,5222.7705250380795,5215.864931890054,5178.834939647022,5144.321271201199,5134.894588491197],"yaxis":"y","type":"scatter"},{"hovertemplate":"campaign_name=Test Campaign\u003cbr\u003ereach=%{x}\u003cbr\u003ewebsite_clicks=%{y}\u003cbr\u003eimpressions=%{marker.size}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","size":[39550.0,100719.0,70263.0,78451.0,114295.0,42684.0,53986.0,33669.0,65827.0,56304.0,94338.0,106584.0,95843.0,53632.0,22521.0,39470.0,133771.0,34752.0,60286.0,36650.0,120576.0,80841.0,111469.0,54627.0,67444.0,120203.0,45511.0,95054.0,83633.0,124591.0],"sizemode":"area","sizeref":363.12,"symbol":"circle"},"mode":"markers","name":"Test Campaign","orientation":"v","showlegend":true,"x":[35820.0,91236.0,45198.0,25937.0,95138.0,31489.0,42148.0,20149.0,49531.0,25982.0,76219.0,81389.0,54389.0,43241.0,10698.0,31893.0,109834.0,27932.0,49329.0,30489.0,105978.0,61589.0,92159.0,41267.0,43219.0,89380.0,31598.0,79632.0,7128 ...

# %% [markdown]
# Some campaigns exhibit high reach but relatively low website clicks. Additionally, there is one campaign with an exceptionally high number of website clicks relative to its reach.

# %%
fig = px.scatter(data_frame=ab_df,
                 x='website_clicks',
                 y='view_content',
                 color='campaign_name',
                 trendline='ols')

fig.update_layout(xaxis_title='Website Clicks',
                  yaxis_title='View Content',
                  title='Trendline of Website Clicks vs. View Content by Campaign',
                  legend_title='Campaign Name')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="48959696-9c80-4dc1-9f72-90fa9fa8fc3b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("48959696-9c80-4dc1-9f72-90fa9fa8fc3b")) {                    Plotly.newPlot(                        "48959696-9c80-4dc1-9f72-90fa9fa8fc3b",                        [{"hovertemplate":"campaign_name=Control Campaign\u003cbr\u003ewebsite_clicks=%{x}\u003cbr\u003eview_content=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Control Campaign","orientation":"v","showlegend":true,"x":[7016.0,8110.0,6508.0,3065.0,5320.793103448276,4028.0,2640.0,7260.0,6554.0,4521.0,4896.0,5224.0,6628.0,7253.0,3706.0,2578.0,5691.0,6843.0,4410.0,4085.0,4234.0,5435.0,4941.0,6287.0,8127.0,4658.0,6198.0,2277.0,8137.0,2993.0],"xaxis":"x","y":[2159.0,1841.0,1549.0,982.0,1943.7931034482758,1249.0,1106.0,2746.0,1975.0,1149.0,1005.0,2158.0,1642.0,2115.0,2098.0,848.0,2496.0,2988.0,2496.0,1149.0,2096.0,2421.0,3249.0,1589.0,4219.0,1249.0,2179.0,1984.0,2486.0,1147.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eview_content = 0.252776 * website_clicks + 598.822\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.326398\u003cbr\u003e\u003cbr\u003ecampaign_name=Control Campaign\u003cbr\u003ewebsite_clicks=%{x}\u003cbr\u003eview_content=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Control Campaign","showlegend":false,"x":[2277.0,2578.0,2640.0,2993.0,3065.0,3706.0,4028.0,4085.0,4234.0,4410.0,4521.0,4658.0,4896.0,4941.0,5224.0,5320.793103448276,5435.0,5691.0,6198.0,6287.0,6508.0,6554.0,6628.0,6843.0,7016.0,7253.0,7260.0,8110.0,8127.0,8137.0],"xaxis":"x","y":[1174.3939511435174,1250.4796563714344,1266.1517949898093,1355.3818745428148,1373.5817774544762,1535.6114686541264,1617.0054788979446,1631.4137353696765,1669.077423339642,1713.5660749014805,1741.6242585569582,1776.2546293749801,1836.4154195551937,1847.7903588749818,1919.3260883749836,1943.7931034482754,1972.661914963324,2037.3726808714528,2165.530330541067,2188.0274327513152,2243.8910236329416,2255.518739382059,2274.224195152377,2328.5711274580317,2372.3014497318845,2432.2094634827695,2433.9788984880697,2648.8388634174034,2653.13606271599,2655.6638270092762],"yaxis":"y","type":"scatter"},{"hovertemplate":"campaign_name=Test Campaign\u003cbr\u003ewebsite_clicks=%{x}\u003cbr\u003eview_content=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Test Campaign","orientation":"v","showlegend":true,"x":[3038.0,4657.0,7885.0,4216.0,5863.0,7488.0,4221.0,7184.0,7568.0,3993.0,4993.0,6800.0,7910.0,6909.0,7617.0,6050.0,5471.0,4431.0,5077.0,7156.0,3596.0,3820.0,6435.0,8144.0,7651.0,4399.0,8259.0,8125.0,3750.0,8264.0],"xaxis":"x","y":[1069.0,1548.0,2367.0,1437.0,858.0,1073.0,2182.0,2194.0,2058.0,1059.0,1609.0,2594.0,1576.0,2522.0,2801.0,1894.0,1868.0,1131.0,2004.0,2427.0,2551.0,1046.0,2552.0,1281.0,1240.0,1625.0,2761.0,1804.0,2617.0,1992.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003eview_content = 0.0980828 * website_clicks + 1266.33\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.078623\u003cbr\u003e\u003cbr\u003ecampaign_name=Test Campaign\u003cbr\u003ewebsite_clicks=%{x}\u003cbr\u003eview_content=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines" ...

# %% [markdown]
# The Test Campaign has a higher number of website clicks than the Control Campaign. However, the Control Campaign has a higher number of content views. This suggests that the Test Campaign was better at attracting users to the website, but the Control Campaign was better at keeping them engaged once they arrived.

# %%
fig = px.scatter(data_frame=ab_df,
                 x='add_to_cart',
                 y='purchase',
                 color='campaign_name',
                 trendline='ols')

fig.update_layout(xaxis_title='Add to Cart',
                  yaxis_title='Purchase',
                  title='Trendline of Add to Cart vs. Purchase by Campaign',
                  legend_title='Campaign Name')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bfd8c16d-e33c-433a-9ff1-48b5681103d3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfd8c16d-e33c-433a-9ff1-48b5681103d3")) {                    Plotly.newPlot(                        "bfd8c16d-e33c-433a-9ff1-48b5681103d3",                        [{"hovertemplate":"campaign_name=Control Campaign\u003cbr\u003eadd_to_cart=%{x}\u003cbr\u003epurchase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Control Campaign","orientation":"v","showlegend":true,"x":[1819.0,1219.0,1134.0,1183.0,1300.0,784.0,1166.0,930.0,1794.0,1339.0,1641.0,1613.0,878.0,1695.0,908.0,1709.0,1460.0,819.0,1913.0,1146.0,883.0,1448.0,980.0,1711.0,1486.0,442.0,645.0,1629.0,1887.0,1439.0],"xaxis":"x","y":[618.0,511.0,372.0,340.0,522.7931034482758,764.0,499.0,462.0,766.0,788.0,366.0,438.0,222.0,243.0,542.0,299.0,800.0,387.0,766.0,585.0,386.0,251.0,605.0,643.0,334.0,670.0,501.0,734.0,475.0,794.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003epurchase = 0.0402096 * add_to_cart + 470.521\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.007841\u003cbr\u003e\u003cbr\u003ecampaign_name=Control Campaign\u003cbr\u003eadd_to_cart=%{x}\u003cbr\u003epurchase=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Control Campaign","marker":{"color":"#636efa","symbol":"circle"},"mode":"lines","name":"Control Campaign","showlegend":false,"x":[442.0,645.0,784.0,819.0,878.0,883.0,908.0,930.0,980.0,1134.0,1146.0,1166.0,1183.0,1219.0,1300.0,1339.0,1439.0,1448.0,1460.0,1486.0,1613.0,1629.0,1641.0,1695.0,1709.0,1711.0,1794.0,1819.0,1887.0,1913.0],"xaxis":"x","y":[488.29326478661824,496.45581402708035,502.0449487286776,503.4522848046193,505.8246513326354,506.02569934348423,507.03093939772833,507.91555064546316,509.92603075395135,516.1183094880951,516.6008247141322,517.4050167575275,518.0885799944135,519.536125672525,522.7931034482759,524.3612779328967,528.3822381498732,528.744124569401,529.2266397954381,530.272089451852,535.378708927412,536.0220625621283,536.5045777881655,538.6758963053328,539.2388307357095,539.319249940049,542.6566469201393,543.6618869743835,546.3961399219274,547.4415895783413],"yaxis":"y","type":"scatter"},{"hovertemplate":"campaign_name=Test Campaign\u003cbr\u003eadd_to_cart=%{x}\u003cbr\u003epurchase=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","symbol":"circle"},"mode":"markers","name":"Test Campaign","orientation":"v","showlegend":true,"x":[894.0,879.0,1268.0,566.0,956.0,882.0,1301.0,1240.0,1391.0,779.0,1090.0,1059.0,383.0,461.0,788.0,1047.0,278.0,367.0,632.0,327.0,1228.0,346.0,992.0,1009.0,1168.0,1034.0,1200.0,424.0,1075.0,1382.0],"xaxis":"x","y":[255.0,677.0,578.0,340.0,768.0,488.0,890.0,431.0,812.0,340.0,398.0,487.0,238.0,257.0,512.0,730.0,245.0,276.0,473.0,269.0,651.0,284.0,771.0,721.0,677.0,572.0,845.0,275.0,668.0,709.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"\u003cb\u003eOLS trendline\u003c\u002fb\u003e\u003cbr\u003epurchase = 0.484969 * add_to_cart + 93.7168\u003cbr\u003eR\u003csup\u003e2\u003c\u002fsup\u003e=0.637951\u003cbr\u003e\u003cbr\u003ecampaign_name=Test Campaign\u003cbr\u003eadd_to_cart=%{x}\u003cbr\u003epurchase=%{y} \u003cb\u003e(trend)\u003c\u002fb\u003e\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Test Campaign","marker":{"color":"#EF553B","symbol":"circle"},"mode":"lines","name":"Test Campaign","showlegend":false,"x":[278.0,327.0,346.0,367.0,383.0,424.0,461.0,566.0,632.0,779.0,788.0,879.0,882.0,894.0,956.0,992.0,1009.0,1034.0,1047.0,1059.0,1075. ...

# %% [markdown]
# The lines show that there is a positive correlation between adds to carts and purchases for both campaigns. This means that as the number of adds to carts increases, the number of purchases also increases. However, the slope of the line for the "Test Campaign" is steeper than the slope of the line for the "Control Campaign". This means that for every one add to cart in the "Test Campaign", there are more purchases than for every one add to cart in the "Control Campaign". In conclusion, the plot suggests that the "Test Campaign" is more effective at converting adds to carts into purchases than the "Control Campaign".

# %% [markdown]
# # 6. Conclusion

# %% [markdown]
# While the Test campaign garnered more initial engagement, the Control campaign might have fostered deeper user connection. Ultimately, the "better" campaign depends on the specific marketing goals and priorities. If immediate purchases were the main objective, the Test campaign might be considered more successful. However, if fostering long-term brand engagement and customer loyalty is equally important, the Control campaign might be seen as more valuable.
